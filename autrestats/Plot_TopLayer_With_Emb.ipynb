# %%
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
file = '/admin/ProjetMLA/Code_Ugo/Resultats/TopLayers/'
Runs = [file+"Run_TopLayer"+str(i)for i in range(11)]
print(Runs)
data = []
file_name = []
for i in range(len(Runs)):
    file = Runs[i]
    for files in os.listdir(file):
        if files.endswith('.npy'):
            file_name.append(files)
            path = os.path.join(file,files)
            data.append(np.load(path,allow_pickle=True))
# Out:
# ['/admin/ProjetMLA/Code_Ugo/Resultats/TopLayers/Run_TopLayer0', '/admin/ProjetMLA/Code_Ugo/Resultats/TopLayers/Run_TopLayer1', '/admin/ProjetMLA/Code_Ugo/Resultats/TopLayers/Run_TopLayer2', '/admin/ProjetMLA/Code_Ugo/Resultats/TopLayers/Run_TopLayer3', '/admin/ProjetMLA/Code_Ugo/Resultats/TopLayers/Run_TopLayer4', '/admin/ProjetMLA/Code_Ugo/Resultats/TopLayers/Run_TopLayer5', '/admin/ProjetMLA/Code_Ugo/Resultats/TopLayers/Run_TopLayer6', '/admin/ProjetMLA/Code_Ugo/Resultats/TopLayers/Run_TopLayer7', '/admin/ProjetMLA/Code_Ugo/Resultats/TopLayers/Run_TopLayer8', '/admin/ProjetMLA/Code_Ugo/Resultats/TopLayers/Run_TopLayer9', '/admin/ProjetMLA/Code_Ugo/Resultats/TopLayers/Run_TopLayer10']

# %%
print(file_name)
# Out:
# ['cola_data.npy', 'sst2_data.npy', 'cola_data.npy', 'sst2_data.npy', 'cola_data.npy', 'sst2_data.npy', 'cola_data.npy', 'sst2_data.npy', 'cola_data.npy', 'sst2_data.npy', 'cola_data.npy', 'sst2_data.npy', 'cola_data.npy', 'sst2_data.npy', 'cola_data.npy', 'sst2_data.npy', 'cola_data.npy', 'sst2_data.npy', 'cola_data.npy', 'sst2_data.npy', 'cola_data.npy', 'sst2_data.npy']

# %%
for i in range(len(data)):
    plt.plot(data[i][0],label="train_accuracy")
    plt.plot(data[i][1],label="val_accuracy")
    plt.title("Accuracy on "+file_name[i]+str(np.round(i/2)))
    plt.legend()
    plt.xlabel("epoch")
    plt.ylabel("Accuracy")
    plt.show()

# %%
for i in range(len(data)):
    plt.plot(data[i][3],label="train_loss")
    plt.plot(data[i][4],label="val_loss")
    plt.title("loss on "+file_name[i])
    plt.legend()
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.show()

# %% [markdown]
# Les meilleurs performances de stabilité, de convergence, et d'overfitting du fine-tuning sur le dataset sst sont atteintes pour un lr=3e-5, et 3 epoch

# %%
for i in range(len(data)):
    print('Accuracy at the end of fine tuning on {}: {}'.format(file_name[i],data[i][2][1]))

# %% [markdown]
# Performance de Bert sur le benchmark
#
#
# CoLA	eval_accuracy	0.6868686315
# SST	eval_accuracy	0.50681818
# MRPC	eval_f1	0.80319616
# QQP	eval_accuracy	0.646484375484375484375890405
