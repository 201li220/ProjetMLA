# %%
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
file = '/admin/ProjetMLA/Code_Nicolas/Resultats/Run_15e/'
data = []
file_name = []
for files in os.listdir(file):
    if files.endswith('.npy'):
        file_name.append(files)
        path = os.path.join(file,files)
        data.append(np.load(path,allow_pickle=True))

# %%
print(file_name)
# Out:
# ['cola_data.npy', 'sst2_data.npy', 'qqp_data.npy', 'mrpc_data.npy']

# %%
for i in range(len(data)):
    plt.plot(data[i][0],label="train_accuracy")
    plt.plot(data[i][1],label="val_accuracy")
    plt.title("Accuracy on "+file_name[i])
    plt.legend()
    plt.xlabel("epoch")
    plt.ylabel("Accuracy")
    plt.show()

# %%
for i in range(len(data)):
    plt.plot(data[i][3],label="train_loss")
    plt.plot(data[i][4],label="val_loss")
    plt.title("loss on "+file_name[i])
    plt.legend()
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.show()

# %%
for i in range(len(data)):
    print('Accuracy at the end of fine tuning on {}: {}'.format(file_name[i],data[i][2][1]))
# Out:
# Accuracy at the end of fine tuning on cola_data.npy: 0.6895933014354068
# Accuracy at the end of fine tuning on sst2_data.npy: 0.6339285714285714
# Accuracy at the end of fine tuning on qqp_data.npy: 0.69296875
# Accuracy at the end of fine tuning on mrpc_data.npy: 0.807288439187465

# %% [markdown]
# 0405
